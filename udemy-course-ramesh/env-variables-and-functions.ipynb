# %%
env = 'dev'

# %%
import os 
import platform

def print_env_info():
    print("Python Version:", platform.python_version())
    print("Spark Version:", spark.version)
    print("Databricks Runtime Version:", os.environ.get("DATABRICKS_RUNTIME_VERSION", "Unknown"))
