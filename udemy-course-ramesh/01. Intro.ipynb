# %% [markdown]
# # Databricks Notebook Intro

# %%
print('hello world')

# %% [markdown]
# ## Magic Commands
# - %python
# - %sql
# - %scala
# - %r
# - %md
# - %fs
# - %sh
# - %pip
# - %run

# %% [markdown]
# ### %fs

# %%
# %fs ls /databricks-datasets/

# %% [markdown]
# %sh

# %%
# %sh ps

# %% [markdown]
# %pip

# %%
# %pip list

# %%
# %pip install faker

# %%
# %run ./env-variables-and-functions

# %%
env

# %%
print_env_info()
